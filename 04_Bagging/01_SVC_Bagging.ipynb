# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import StratifiedKFold, GridSearchCV, cross_validate, train_test_split
from sklearn.metrics import confusion_matrix, make_scorer
from sklearn.preprocessing import PowerTransformer
from sklearn.svm import SVC
from sklearn.base import clone

from sklearn.pipeline import Pipeline

import os
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

#Set a random state
rs = 4

#Set our CVs
cv_outer = StratifiedKFold(n_splits=5, shuffle=True, random_state=rs)
cv_inner = StratifiedKFold(n_splits=3, shuffle=True, random_state=rs)

#Set the scaler
scaler = PowerTransformer()

# %%
#Get current directory 
path = os.getcwd() 

#Get parent directory 
parent = os.path.dirname(path)

#Move to the directory with data
train_csv = os.path.join(parent, "data", "train.csv")

#Import our dataset
dataset = pd.read_csv(train_csv, delimiter = '|')

#Clean the dataset (drop unrealistic entries)
dataset_org = dataset.copy()
dataset = dataset[dataset['scannedLineItemsPerSecond'] < 4]
cutted = len(dataset_org)-len(dataset)
print(f"{cutted} entries removed due to errors in feature 'scannedLineItemsPerSecond'.")

#Add new feature 'totalItems'
dataset = dataset.assign(totalItems = dataset.totalScanTimeInSeconds * dataset.scannedLineItemsPerSecond)

#Add new feature 'suspicious' as frauds only occur at trustLevels 1-2, all others are non-fraudulent
suspicious = dataset['trustLevel'].copy()
suspicious[suspicious > 2] = 3
dataset = dataset.assign(suspicious = suspicious)

#Drop 'trustLevel' as it is too similar to 'suspicious'
dataset = dataset.drop("trustLevel", axis=1)

#Add new feature 'avgLineItemValue'
dataset = dataset.assign(avgLineItemValue = dataset.valuePerSecond / dataset.scannedLineItemsPerSecond)
# Out:
# 4 entries removed due to errors in feature 'scannedLineItemsPerSecond'.

# %%
#Split the dataset in X and y
X = dataset.drop('fraud', axis=1)
y = dataset.fraud

# %%
X.head()
# Out:
#    totalScanTimeInSeconds  grandTotal  lineItemVoids  \
# 0                    1054       54.70              7
# 1                     108       27.36              5
# 2                    1516       62.16              3
# 3                    1791       92.31              8
# 4                     430       81.53              3
#
#    scansWithoutRegistration  quantityModifications  scannedLineItemsPerSecond  \
# 0                         0                      3                   0.027514
# 1                         2                      4                   0.129630
# 2                        10                      5                   0.008575
# 3                         4                      4                   0.016192
# 4                         7                      2                   0.062791
#
#    valuePerSecond  lineItemVoidsPerPosition  totalItems  suspicious  \
# 0        0.051898                  0.241379        29.0           3
# 1        0.253333                  0.357143        14.0           3
# 2        0.041003                  0.230769        13.0           3
# 3        0.051541                  0.275862        29.0           3
# 4        0.189605                  0.111111        27.0           3
#
#    avgLineItemValue
# 0          1.886207
# 1          1.954286
# 2          4.781538
# 3          3.183103
# 4          3.019630

# %%
#Define monetary_score as our used metric
def monetary_score_func(y_test, y_pred):
    cm = confusion_matrix(y_test, y_pred)
    monetary_value = (cm[0,0] * 0) + (cm[1, 0] * -5) + (cm[0, 1] * -25) + (cm[1, 1] * 5)
    max_monetary_value = (cm[1,0] + cm[1,1]) * 5
    return (monetary_value / max_monetary_value)

monetary_score = make_scorer(monetary_score_func)

# %%
#Define model and parameters
model = BaggingClassifier(base_estimator=SVC(kernel="linear"), random_state=rs, n_jobs=-1)
params = {"model__bootstrap": [True, False], #Are samples drawn with or without replacement? False = without replacement (Pasting), True = with replacement (Bagging)
          "model__max_samples": [0.25, 0.5, 0.75, 1.0], #Used number of samples to train the base estimators
          "model__n_estimators": [5, 10, 25, 50] #Number of base estimators
         }

#Create the model pipeline
try:
    pipe_model = Pipeline([
        ('sampler', sampler),
        ("scaler", scaler),
        ("model", model)
    ])
    
except NameError:
    pipe_model = Pipeline([    
        ("scaler", scaler),
        ("model", model)
    ])

#Define the grid search (inner cv)
grid = GridSearchCV(estimator=pipe_model, param_grid=params, scoring=monetary_score, cv=cv_inner, n_jobs=-1)
print(pipe_model)
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  PowerTransformer(copy=True, method='yeo-johnson',
#                                   standardize=True)),
#                 ('model',
#                  BaggingClassifier(base_estimator=SVC(C=1.0, break_ties=False,
#                                                       cache_size=200,
#                                                       class_weight=None,
#                                                       coef0=0.0,
#                                                       decision_function_shape='ovr',
#                                                       degree=3, gamma='scale',
#                                                       kernel='linear',
#                                                       max_iter=-1,
#                                                       probability=False,
#                                                       random_state=None,
#                                                       shrinking=True, tol=0.001,
#                                                       verbose=False),
#                                    bootstrap=True, bootstrap_features=False,
#                                    max_features=1.0, max_samples=1.0,
#                                    n_estimators=10, n_jobs=-1, oob_score=False,
#                                    random_state=4, verbose=0,
#                                    warm_start=False))],
#          verbose=False)

# %%
#Get the mean nested score to have an estimate on the expected performance
nested_cv = cross_validate(estimator=grid, X=X, y=y, cv=cv_outer, scoring=monetary_score, n_jobs=-1)
nested_score = nested_cv["test_score"].mean()

print(f"Scores of nested folds:\t\t{nested_cv['test_score']}")
print(f"Mean score of nested folds:\t{nested_score}")
# Out:
# Scores of nested folds:		[0.5        0.57142857 0.23809524 0.66666667 0.33333333]
# Mean score of nested folds:	0.46190476190476193

# %%
#Fit the data to the GridSearch
grid.fit(X, y)

#Get the GridSearch results
results = pd.DataFrame(grid.cv_results_)

#Sort the output by mean_test_score
results.sort_values(by='mean_test_score', inplace=True, ignore_index=True, ascending=False)

#Drop everything but the param columns
results_grid = results.drop(["mean_fit_time", "std_fit_time", "mean_score_time", "std_score_time", "split0_test_score", "split1_test_score", "split2_test_score", "rank_test_score", "mean_test_score", "std_test_score"], axis=1)

#Get back mean_test_score and std_test_score (as double_std_test_score) to insert them in the first two columns
results_grid.insert(0, "mean_test_score", results["mean_test_score"])
results_grid.insert(1, "double_std_test_score", results["std_test_score"] * 2)

# %%
#See the top results (sorted by 'mean_test_score')
results_grid
# Out:
#     mean_test_score  double_std_test_score param_model__bootstrap  \
# 0          0.626331               0.207830                   True
# 1          0.625210               0.212218                  False
# 2          0.568627               0.253662                  False
# 3          0.568627               0.253662                  False
# 4          0.550140               0.325088                   True
# 5          0.549580               0.249933                  False
# 6          0.549580               0.249933                  False
# 7          0.549580               0.249933                  False
# 8          0.549580               0.249933                  False
# 9          0.540056               0.234514                   True
# 10         0.540056               0.299711                   True
# 11         0.538375               0.326845                   True
# 12         0.519888               0.430894                   True
# 13         0.511485               0.345923                   True
# 14         0.510364               0.237085                  False
# 15         0.500840               0.154865                   True
# 16         0.483193               0.375120                  False
# 17         0.473389               0.336161                   True
# 18         0.469188               0.303864                   True
# 19         0.463305               0.349217                   True
# 20         0.463305               0.295165                   True
# 21         0.462185               0.105905                  False
# 22         0.453221               0.319856                   True
# 23         0.445098               0.426653                  False
# 24         0.444258               0.342179                  False
# 25         0.444258               0.342179                   True
# 26         0.444258               0.342179                   True
# 27         0.425770               0.437899                  False
# 28         0.415686               0.334611                  False
# 29         0.396078               0.295726                   True
# 30         0.386835               0.445557                  False
# 31         0.348459               0.339094                  False
#
#    param_model__max_samples param_model__n_estimators  \
# 0                      0.25                        50
# 1                       0.5                        25
# 2                      0.75                        25
# 3                      0.75                        50
# 4                      0.25                        25
# 5                         1                         5
# 6                         1                        50
# 7                         1                        10
# 8                         1                        25
# 9                      0.75                         5
# 10                     0.25                        10
# 11                        1                        10
# 12                      0.5                        10
# 13                        1                        50
# 14                     0.75                        10
# 15                     0.75                        10
# 16                      0.5                        10
# 17                        1                         5
# 18                     0.25                         5
# 19                     0.75                        50
# 20                      0.5                         5
# 21                      0.5                         5
# 22                      0.5                        50
# 23                     0.25                        25
# 24                      0.5                        50
# 25                        1                        25
# 26                     0.75                        25
# 27                     0.25                        10
# 28                     0.75                         5
# 29                      0.5                        25
# 30                     0.25                         5
# 31                     0.25                        50
#
#                                                params
# 0   {'model__bootstrap': True, 'model__max_samples...
# 1   {'model__bootstrap': False, 'model__max_sample...
# 2   {'model__bootstrap': False, 'model__max_sample...
# 3   {'model__bootstrap': False, 'model__max_sample...
# 4   {'model__bootstrap': True, 'model__max_samples...
# 5   {'model__bootstrap': False, 'model__max_sample...
# 6   {'model__bootstrap': False, 'model__max_sample...
# 7   {'model__bootstrap': False, 'model__max_sample...
# 8   {'model__bootstrap': False, 'model__max_sample...
# 9   {'model__bootstrap': True, 'model__max_samples...
# 10  {'model__bootstrap': True, 'model__max_samples...
# 11  {'model__bootstrap': True, 'model__max_samples...
# 12  {'model__bootstrap': True, 'model__max_samples...
# 13  {'model__bootstrap': True, 'model__max_samples...
# 14  {'model__bootstrap': False, 'model__max_sample...
# 15  {'model__bootstrap': True, 'model__max_samples...
# 16  {'model__bootstrap': False, 'model__max_sample...
# 17  {'model__bootstrap': True, 'model__max_samples...
# 18  {'model__bootstrap': True, 'model__max_samples...
# 19  {'model__bootstrap': True, 'model__max_samples...
# 20  {'model__bootstrap': True, 'model__max_samples...
# 21  {'model__bootstrap': False, 'model__max_sample...
# 22  {'model__bootstrap': True, 'model__max_samples...
# 23  {'model__bootstrap': False, 'model__max_sample...
# 24  {'model__bootstrap': False, 'model__max_sample...
# 25  {'model__bootstrap': True, 'model__max_samples...
# 26  {'model__bootstrap': True, 'model__max_samples...
# 27  {'model__bootstrap': False, 'model__max_sample...
# 28  {'model__bootstrap': False, 'model__max_sample...
# 29  {'model__bootstrap': True, 'model__max_samples...
# 30  {'model__bootstrap': False, 'model__max_sample...
# 31  {'model__bootstrap': False, 'model__max_sample...

# %%
#Use best model as final_clf
final_pipe = clone(pipe_model)
final_pipe = final_pipe.set_params(**results_grid.loc[0, "params"])
print(final_pipe)

#How does the model perform?
cv_results = cross_validate(final_pipe, X, y, cv=cv_inner, scoring=monetary_score, n_jobs=-1)
print("\n\nPerformance on folds:\t\t",cv_results['test_score'])
print("Mean monetary score:\t\t", cv_results['test_score'].mean())
print("Double Standard Deviation:\t", 2*cv_results['test_score'].std())
# Out:
# Pipeline(memory=None,
#          steps=[('scaler',
#                  PowerTransformer(copy=True, method='yeo-johnson',
#                                   standardize=True)),
#                 ('model',
#                  BaggingClassifier(base_estimator=SVC(C=1.0, break_ties=False,
#                                                       cache_size=200,
#                                                       class_weight=None,
#                                                       coef0=0.0,
#                                                       decision_function_shape='ovr',
#                                                       degree=3, gamma='scale',
#                                                       kernel='linear',
#                                                       max_iter=-1,
#                                                       probability=False,
#                                                       random_state=None,
#                                                       shrinking=True, tol=0.001,
#                                                       verbose=False),
#                                    bootstrap=True, bootstrap_features=False,
#                                    max_features=1.0, max_samples=0.25,
#                                    n_estimators=50, n_jobs=-1, oob_score=False,
#                                    random_state=4, verbose=0,
#                                    warm_start=False))],
#          verbose=False)
#
#
# Performance on folds:		 [0.76470588 0.51428571 0.6       ]
# Mean monetary score:		 0.6263305322128851
# Double Standard Deviation:	 0.20783030153574736
