# %%
import pandas as pd

# %%
#Load the results if we want to look at them again
results_grid = pd.read_pickle("stacking_results.pkl")

# %%
#See the top results (sorted by 'mean_test_score')
results_grid[:30]

#See the top results (sorted by 'double_std_test_score')
results_grid[:60].sort_values(by='double_std_test_score')
# Out:
#     mean_test_score  double_std_test_score  \
# 59         0.538375               0.012676
# 50         0.557983               0.042783
# 10         0.634734               0.049806
# 57         0.538936               0.083892
# 27         0.596639               0.085213
# 29         0.596639               0.085213
# 3          0.653782               0.093797
# 4          0.653782               0.093797
# 37         0.577591               0.098242
# 15         0.615686               0.103325
# 16         0.615686               0.103325
# 17         0.615686               0.103325
# 18         0.615686               0.103325
# 19         0.615686               0.103325
# 20         0.615686               0.103325
# 39         0.577031               0.140865
# 30         0.596639               0.157087
# 28         0.596639               0.157087
# 24         0.604762               0.175093
# 52         0.548179               0.187234
# 53         0.548179               0.187234
# 54         0.548179               0.187234
# 49         0.557983               0.191469
# 0          0.731092               0.192587
# 38         0.577591               0.210906
# 7          0.635294               0.211649
# 8          0.635294               0.211649
# 9          0.635294               0.211649
# 25         0.604482               0.222397
# 35         0.585434               0.230317
# 1          0.662465               0.237304
# 26         0.597199               0.241773
# 23         0.605322               0.242376
# 58         0.538936               0.243480
# 2          0.654342               0.244407
# 21         0.614566               0.262534
# 51         0.556863               0.263265
# 48         0.558543               0.264748
# 13         0.624370               0.294890
# 31         0.595238               0.331833
# 5          0.652101               0.346865
# 34         0.586555               0.349935
# 56         0.546779               0.358372
# 55         0.547339               0.366375
# 44         0.565826               0.373420
# 45         0.565826               0.373420
# 11         0.632493               0.389697
# 12         0.632493               0.389697
# 46         0.565266               0.394986
# 47         0.565266               0.394986
# 6          0.651541               0.439718
# 41         0.575910               0.445547
# 40         0.575910               0.445547
# 36         0.584314               0.446138
# 14         0.622969               0.460069
# 22         0.614006               0.466330
# 33         0.594398               0.492987
# 32         0.594958               0.498621
# 42         0.575350               0.520776
# 43         0.575350               0.520776
#
#                               param_model__estimators  \
# 59  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 50  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 10  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 57  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 27  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 29  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 3   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 4   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 37  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 15  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 16  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 17  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 18  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 19  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 20  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 39  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 30  ((LR, LogisticRegression(C=0.3, n_jobs=-1, ran...
# 28  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 24  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 52  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 53  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 54  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 49  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 0   ((Ada, BaggingClassifier(base_estimator=AdaBoo...
# 38  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 7   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 8   ((LR, LogisticRegression(C=0.3, n_jobs=-1, ran...
# 9   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 25  ((LR, LogisticRegression(C=0.3, n_jobs=-1, ran...
# 35  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 1   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 26  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 23  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 58  ((LR, LogisticRegression(C=0.3, n_jobs=-1, ran...
# 2   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 21  ((Ada, BaggingClassifier(base_estimator=AdaBoo...
# 51  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 48  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 13  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 31  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 5   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 34  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 56  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 55  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 44  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 45  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 11  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 12  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 46  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 47  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 6   ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 41  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 40  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 36  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 14  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 22  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 33  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 32  ((XG, XGBClassifier(alpha=0.00075, base_score=...
# 42  ((SVC, SVC(C=0.6, kernel='linear', probability...
# 43  ((XG, XGBClassifier(alpha=0.00075, base_score=...
#
#                          param_model__final_estimator  \
# 59  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 50  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 10  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 57  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 27  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 29  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 3   LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 4   LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 37  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 15  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 16  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 17  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 18  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 19  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 20  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 39  SVC(C=0.6, kernel='linear', probability=True, ...
# 30  XGBClassifier(alpha=0.00075, base_score=None, ...
# 28  XGBClassifier(alpha=0.00075, base_score=None, ...
# 24  XGBClassifier(alpha=0.00075, base_score=None, ...
# 52  SVC(C=0.6, kernel='linear', probability=True, ...
# 53  SVC(C=0.6, kernel='linear', probability=True, ...
# 54  SVC(C=0.6, kernel='linear', probability=True, ...
# 49  LogisticRegression(C=0.3, n_jobs=-1, random_st...
# 0   VotingClassifier(estimators=[('MLP1',\n       ...
# 38  SVC(C=0.6, kernel='linear', probability=True, ...
# 7   XGBClassifier(alpha=0.00075, base_score=None, ...
# 8   XGBClassifier(alpha=0.00075, base_score=None, ...
# 9   XGBClassifier(alpha=0.00075, base_score=None, ...
# 25  VotingClassifier(estimators=[('MLP1',\n       ...
# 35  VotingClassifier(estimators=[('MLP1',\n       ...
# 1   VotingClassifier(estimators=[('MLP1',\n       ...
# 26  SVC(C=0.6, kernel='linear', probability=True, ...
# 23  XGBClassifier(alpha=0.00075, base_score=None, ...
# 58  SVC(C=0.6, kernel='linear', probability=True, ...
# 2   XGBClassifier(alpha=0.00075, base_score=None, ...
# 21  SVC(C=0.6, kernel='linear', probability=True, ...
# 51  VotingClassifier(estimators=[('MLP1',\n       ...
# 48  VotingClassifier(estimators=[('MLP1',\n       ...
# 13  XGBClassifier(alpha=0.00075, base_score=None, ...
# 31  XGBClassifier(alpha=0.00075, base_score=None, ...
# 5   VotingClassifier(estimators=[('MLP1',\n       ...
# 34  SVC(C=0.6, kernel='linear', probability=True, ...
# 56  VotingClassifier(estimators=[('MLP1',\n       ...
# 55  VotingClassifier(estimators=[('MLP1',\n       ...
# 44  XGBClassifier(alpha=0.00075, base_score=None, ...
# 45  XGBClassifier(alpha=0.00075, base_score=None, ...
# 11  XGBClassifier(alpha=0.00075, base_score=None, ...
# 12  XGBClassifier(alpha=0.00075, base_score=None, ...
# 46  XGBClassifier(alpha=0.00075, base_score=None, ...
# 47  XGBClassifier(alpha=0.00075, base_score=None, ...
# 6   XGBClassifier(alpha=0.00075, base_score=None, ...
# 41  VotingClassifier(estimators=[('MLP1',\n       ...
# 40  VotingClassifier(estimators=[('MLP1',\n       ...
# 36  XGBClassifier(alpha=0.00075, base_score=None, ...
# 14  XGBClassifier(alpha=0.00075, base_score=None, ...
# 22  VotingClassifier(estimators=[('MLP1',\n       ...
# 33  VotingClassifier(estimators=[('MLP1',\n       ...
# 32  VotingClassifier(estimators=[('MLP1',\n       ...
# 42  VotingClassifier(estimators=[('MLP1',\n       ...
# 43  VotingClassifier(estimators=[('MLP1',\n       ...
#
#                                                params
# 59  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 50  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 10  {'model__estimators': (('XG', XGBClassifier(al...
# 57  {'model__estimators': (('XG', XGBClassifier(al...
# 27  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 29  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 3   {'model__estimators': (('XG', XGBClassifier(al...
# 4   {'model__estimators': (('XG', XGBClassifier(al...
# 37  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 15  {'model__estimators': (('XG', XGBClassifier(al...
# 16  {'model__estimators': (('XG', XGBClassifier(al...
# 17  {'model__estimators': (('XG', XGBClassifier(al...
# 18  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 19  {'model__estimators': (('XG', XGBClassifier(al...
# 20  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 39  {'model__estimators': (('XG', XGBClassifier(al...
# 30  {'model__estimators': (('LR', LogisticRegressi...
# 28  {'model__estimators': (('XG', XGBClassifier(al...
# 24  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 52  {'model__estimators': (('XG', XGBClassifier(al...
# 53  {'model__estimators': (('XG', XGBClassifier(al...
# 54  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 49  {'model__estimators': (('XG', XGBClassifier(al...
# 0   {'model__estimators': (('Ada', BaggingClassifi...
# 38  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 7   {'model__estimators': (('XG', XGBClassifier(al...
# 8   {'model__estimators': (('LR', LogisticRegressi...
# 9   {'model__estimators': (('XG', XGBClassifier(al...
# 25  {'model__estimators': (('LR', LogisticRegressi...
# 35  {'model__estimators': (('XG', XGBClassifier(al...
# 1   {'model__estimators': (('XG', XGBClassifier(al...
# 26  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 23  {'model__estimators': (('XG', XGBClassifier(al...
# 58  {'model__estimators': (('LR', LogisticRegressi...
# 2   {'model__estimators': (('XG', XGBClassifier(al...
# 21  {'model__estimators': (('Ada', BaggingClassifi...
# 51  {'model__estimators': (('XG', XGBClassifier(al...
# 48  {'model__estimators': (('XG', XGBClassifier(al...
# 13  {'model__estimators': (('XG', XGBClassifier(al...
# 31  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 5   {'model__estimators': (('XG', XGBClassifier(al...
# 34  {'model__estimators': (('XG', XGBClassifier(al...
# 56  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 55  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 44  {'model__estimators': (('XG', XGBClassifier(al...
# 45  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 11  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 12  {'model__estimators': (('XG', XGBClassifier(al...
# 46  {'model__estimators': (('XG', XGBClassifier(al...
# 47  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 6   {'model__estimators': (('XG', XGBClassifier(al...
# 41  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 40  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 36  {'model__estimators': (('XG', XGBClassifier(al...
# 14  {'model__estimators': (('XG', XGBClassifier(al...
# 22  {'model__estimators': (('XG', XGBClassifier(al...
# 33  {'model__estimators': (('XG', XGBClassifier(al...
# 32  {'model__estimators': (('XG', XGBClassifier(al...
# 42  {'model__estimators': (('SVC', SVC(C=0.6, kern...
# 43  {'model__estimators': (('XG', XGBClassifier(al...
